# %% [markdown]
# # Standardization

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn import preprocessing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.decomposition import PCA
from io import BytesIO
from sklearn.linear_model import LinearRegression
from sklearn.cross_validation import train_test_split
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
from IPython.html import widgets
from IPython.html.widgets import interact
from IPython.display import display
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ### 1. Read the CSV

# %%
df = pd.read_csv('./Data/FinalDataset.csv')
df
# Out:
#                Name  Confidence  Brightness  FaceArea  EyesDistance  \
# 0      S01_1001.pgm    0.000000    0.000000  0.000000      0.000000
# 1      S01_1005.pgm    0.000000    0.000000  0.000000      0.000000
# 2      S01_1006.pgm    0.000000    0.000000  0.000000      0.000000
# 3      S01_1007.pgm    0.000000    0.000000  0.000000      0.000000
# 4      S01_1011.pgm    0.000000    0.000000  0.000000      0.000000
# 5      S01_1012.pgm    0.000000    0.000000  0.000000      0.000000
# 6      S01_1018.pgm    0.000000    0.000000  0.000000      0.000000
# 7      S01_1019.pgm    0.000000    0.000000  0.000000      0.000000
# 8      S01_1020.pgm    0.000000    0.000000  0.000000      0.000000
# 9      S01_1021.pgm    0.000000    0.000000  0.000000      0.000000
# 10     S01_1023.pgm    0.000000    0.000000  0.000000      0.000000
# 11     S01_1024.pgm    0.000000    0.000000  0.000000      0.000000
# 12     S01_1025.pgm    0.000000    0.000000  0.000000      0.000000
# ...

# %% [markdown]
# ## 2. Data Preprocessing

# %% [markdown]
# ### A) Fill NaN

# %%
df = df.fillna(2)
dfT = df[['Brightness', 'FaceArea', 'Sharpness', 'EyesDistance', 'MouthDistance']].values
dfY = df[['Eyeglass','EyesOpen','Gender','Moustache','Beard']]
#X = df.values[:,2:13]
#Y = df.values[:,12]
print "Before Standardization: ", dfT
print dfT.shape
# Out:
# Before Standardization:  [[  0.00000000e+00   0.00000000e+00   3.20455946e+02   0.00000000e+00
#     0.00000000e+00]
#  [  0.00000000e+00   0.00000000e+00   3.46844296e+02   0.00000000e+00
#     0.00000000e+00]
#  [  0.00000000e+00   0.00000000e+00   3.79592133e+02   0.00000000e+00
#     0.00000000e+00]
#  ...,
#  [  4.38019562e+01   8.78906250e-01   1.62698115e+02   3.49294019e-01
#     2.84998036e-01]
#  [  4.19072723e+01   9.40029656e-01   2.51887272e+01   3.51864793e-01
#     2.81385604e-01]
#  [  4.53301086e+01   9.09211189e-01   3.12053015e+02   3.46078499e-01
#     2.78913713e-01]]
# (29005, 5)

# %% [markdown]
# ### B) Standardization

# %%
std_scale = preprocessing.StandardScaler().fit(dfT)
X_std = std_scale.transform(dfT)
np.set_printoptions(precision=3)
X_std.shape
# Out:
# (29005, 5)

# %%
result = np.concatenate([dfT, dfY], axis=1)
result.shape
# Out:
# (29005, 10)

# %%
np.savetxt("./Data/Quality.csv", result, delimiter=",")

### C) Min Max Scaling

# %%
mm_scaler = MinMaxScaler(feature_range=(0, 1))
X_mm = mm_scaler.fit_transform(X)
np.set_printoptions(precision=3)
X_mm

# %%
dfT = mm_scaler.fit_transform(dfT)
np.savetxt("foo.csv", dfT, delimiter=",")
